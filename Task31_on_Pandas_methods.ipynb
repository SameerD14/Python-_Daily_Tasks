# %%
import pandas as pd
df = pd.read_csv("C:/Users/hp/Downloads/Bank_customer_churn - Bank_customer_churn.csv")

# %% [markdown]
# ##### Q1  Load the dataset and display the first 10 records.

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %% [markdown]
# ######  Q2 Display the last 15 customers.

# %%
df.tail(15)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9985       9986    15586914       Nepean          659    France    Male   36
# 9986       9987    15581736     Bartlett          673   Germany    Male   47
# 9987       9988    15588839      Mancini          606     Spain    Male   30
# 9988       9989    15589329      Pirozzi          775    France    Male   30
# 9989       9990    15605622     McMillan          841     Spain    Male   28
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9994       9995    15719294         Wood          800    France  Female   29
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# ...

# %% [markdown]
# ##### Q3 Show 7 random customer records.

# %%
df.sample(7)
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 7665       7666    15730150  Otutodilichukwu          540     Spain    Male
# 7129       7130    15781875         Jamieson          850     Spain    Male
# 7986       7987    15678067            Boyle          667     Spain    Male
# 5589       5590    15588372          Kirsova          715   Germany  Female
# 5658       5659    15814430               Ma          747     Spain    Male
# 4976       4977    15717056              Pan          828   Germany  Female
# 6833       6834    15686964           Spence          675    France  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7665   37       0  120825.70              1          1               0
# 7129   33       3  100476.46              2          1               1
# 7986   45       3       0.00              2          0               0
# 5589   37       9  105489.31              1          0               0
# ...

# %% [markdown]
# ##### Q4 Print complete dataset information and identify:
# ##### • Total columns
# ##### • Data type of each column
# ##### • Missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ##### Q5 Find missing values in every column.

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ##### Q6 Display only numerical columns.

# %%
df.select_dtypes(include="int")
# Out:
#       RowNumber  CustomerId  CreditScore  Age  Tenure  NumOfProducts  \
# 0             1    15634602          619   42       2              1
# 1             2    15647311          608   41       1              1
# 2             3    15619304          502   42       8              3
# 3             4    15701354          699   39       1              2
# 4             5    15737888          850   43       2              1
# ...         ...         ...          ...  ...     ...            ...
# 9995       9996    15606229          771   39       5              2
# 9996       9997    15569892          516   35      10              1
# 9997       9998    15584532          709   36       7              1
# 9998       9999    15682355          772   42       3              2
# 9999      10000    15628319          792   28       4              1
#
#       HasCrCard  IsActiveMember  Exited
# 0             1               1       1
# 1             0               1       0
# ...

# %% [markdown]
# ##### Q7 Generate the statistical summary of numerical columns.

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# ##### Q8 Find duplicate rows and print how many exist.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Q9 Remove duplicate rows and store the cleaned dataset.

# %%
df.drop_duplicates()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ##### Q10 Count how many customers have exited and how many have not exited.

# %%
counts=df["Exited"].value_counts()
print("Exited=",counts[0])
print("Not Exited=",counts[1])
# Out:
# Exited= 7963
# Not Exited= 2037

# %% [markdown]
# ##### Medium Level (11–20)
# ##### Q11
# ##### Rename the following columns:
# ##### CustomerId → Customer_ID
# ##### CreditScore → Credit_Score
# ##### EstimatedSalary → Salary
# ##### Exited → Churn

# %%
df.rename(columns={"CustomerId":"Customer_Id", "CreditScore":"Credit_Score","EstimatedSalary":"Salary","Exited":"Churn"})
# Out:
#       RowNumber  Customer_Id    Surname  Credit_Score Geography  Gender  Age  \
# 0             1     15634602   Hargrave           619    France  Female   42
# 1             2     15647311       Hill           608     Spain  Female   41
# 2             3     15619304       Onio           502    France  Female   42
# 3             4     15701354       Boni           699    France  Female   39
# 4             5     15737888   Mitchell           850     Spain  Female   43
# ...         ...          ...        ...           ...       ...     ...  ...
# 9995       9996     15606229   Obijiaku           771    France    Male   39
# 9996       9997     15569892  Johnstone           516    France    Male   35
# 9997       9998     15584532        Liu           709    France  Female   36
# 9998       9999     15682355  Sabbatini           772   Germany    Male   42
# 9999      10000     15628319     Walker           792    France  Female   28
#
# ...

# %% [markdown]
# ##### Q12 Add the prefix Bank_to every column name.

# %%
df.add_prefix("Bank_")
# Out:
#       Bank_RowNumber  Bank_CustomerId Bank_Surname  Bank_CreditScore  \
# 0                  1         15634602     Hargrave               619
# 1                  2         15647311         Hill               608
# 2                  3         15619304         Onio               502
# 3                  4         15701354         Boni               699
# 4                  5         15737888     Mitchell               850
# ...              ...              ...          ...               ...
# 9995            9996         15606229     Obijiaku               771
# 9996            9997         15569892    Johnstone               516
# 9997            9998         15584532          Liu               709
# 9998            9999         15682355    Sabbatini               772
# 9999           10000         15628319       Walker               792
#
#      Bank_Geography Bank_Gender  Bank_Age  Bank_Tenure  Bank_Balance  \
# ...

# %% [markdown]
# ##### Q13 Convert the Age column into float datatype.

# %%
df["Age"]=df["Age"].astype(float)
# df["Age"].dtypes
df["Age"]
# Out:
# 0       42.0
# 1       41.0
# 2       42.0
# 3       39.0
# 4       43.0
#         ...
# 9995    39.0
# 9996    35.0
# 9997    36.0
# 9998    42.0
# 9999    28.0
# Name: Age, Length: 10000, dtype: float64

# %% [markdown]
# ##### Q14 Convert the Exited column into string datatype.

# %%
df["Exited"]=df["Exited"].astype(str)
df["Exited"]
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: object

# %% [markdown]
# ##### Q15 Suppose the Balance column has missing values.
# ##### Replace them using the mean of the Balance column.

# %%
df["Balance"].fillna(df["Balance"].mean())
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %% [markdown]
# ##### Q16 Suppose the Age column has missing values.
# ##### Replace them using the median age.

# %%
df["Age"].fillna(df["Age"].median())
# Out:
# 0       42.0
# 1       41.0
# 2       42.0
# 3       39.0
# 4       43.0
#         ...
# 9995    39.0
# 9996    35.0
# 9997    36.0
# 9998    42.0
# 9999    28.0
# Name: Age, Length: 10000, dtype: float64

# %% [markdown]
# ##### Q17 Display only the first five rows after renaming the columns.

# %%
df.rename(columns={"CustomerId":"Customer_Id","Age":"age"})
# Out:
#       RowNumber  Customer_Id    Surname  CreditScore Geography  Gender   age  \
# 0             1     15634602   Hargrave          619    France  Female  42.0
# 1             2     15647311       Hill          608     Spain  Female  41.0
# 2             3     15619304       Onio          502    France  Female  42.0
# 3             4     15701354       Boni          699    France  Female  39.0
# 4             5     15737888   Mitchell          850     Spain  Female  43.0
# ...         ...          ...        ...          ...       ...     ...   ...
# 9995       9996     15606229   Obijiaku          771    France    Male  39.0
# 9996       9997     15569892  Johnstone          516    France    Male  35.0
# 9997       9998     15584532        Liu          709    France  Female  36.0
# 9998       9999     15682355  Sabbatini          772   Germany    Male  42.0
# 9999      10000     15628319     Walker          792    France  Female  28.0
#
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary Exited
# 0        101348.88      1
# 1        112542.58      0
# 2        113931.57      1
# 3         93826.63      0
# ...

# %% [markdown]
# ##### Q18 Create a new DataFrame by dropping these columns:
# ##### RowNumber
# ##### CustomerId
# ##### Surname
# ##### Display the first 10 rows.

# %%
Drop=df.drop(columns=["RowNumber", "CustomerId" ,"Surname"])
Drop.head(10)
# Out:
#    CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female  42.0       2       0.00              1
# 1          608     Spain  Female  41.0       1   83807.86              1
# 2          502    France  Female  42.0       8  159660.80              3
# 3          699    France  Female  39.0       1       0.00              2
# 4          850     Spain  Female  43.0       2  125510.82              1
# 5          645     Spain    Male  44.0       8  113755.78              2
# 6          822    France    Male  50.0       7       0.00              2
# 7          376   Germany  Female  29.0       4  115046.74              4
# 8          501    France    Male  44.0       4  142051.07              2
# 9          684    France    Male  27.0       2  134603.88              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary Exited
# 0          1               1        101348.88      1
# 1          0               1        112542.58      0
# ...

# %% [markdown]
# ##### Q19 Drop the Geography column and display dataset information again.

# %%
Drop=df.drop(columns="Geography")
Drop
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Gender   Age  Tenure  \
# 0             1    15634602   Hargrave          619  Female  42.0       2
# 1             2    15647311       Hill          608  Female  41.0       1
# 2             3    15619304       Onio          502  Female  42.0       8
# 3             4    15701354       Boni          699  Female  39.0       1
# 4             5    15737888   Mitchell          850  Female  43.0       2
# ...         ...         ...        ...          ...     ...   ...     ...
# 9995       9996    15606229   Obijiaku          771    Male  39.0       5
# 9996       9997    15569892  Johnstone          516    Male  35.0      10
# 9997       9998    15584532        Liu          709  Female  36.0       7
# 9998       9999    15682355  Sabbatini          772    Male  42.0       3
# 9999      10000    15628319     Walker          792  Female  28.0       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %% [markdown]
# ##### Q20 Rename NumOfProducts to Products and HasCrCard to CreditCard.

# %%
df.rename(columns={"NumOfProducts":"Products","HasCrCard":"CreditCard"})
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0             1    15634602   Hargrave          619    France  Female  42.0
# 1             2    15647311       Hill          608     Spain  Female  41.0
# 2             3    15619304       Onio          502    France  Female  42.0
# 3             4    15701354       Boni          699    France  Female  39.0
# 4             5    15737888   Mitchell          850     Spain  Female  43.0
# ...         ...         ...        ...          ...       ...     ...   ...
# 9995       9996    15606229   Obijiaku          771    France    Male  39.0
# 9996       9997    15569892  Johnstone          516    France    Male  35.0
# 9997       9998    15584532        Liu          709    France  Female  36.0
# 9998       9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
df.rename(columns={
    "RowNumber":"Row_No",
    "CustomerId":"Customer_ID",
    "Surname":"Last_Name",
    "CreditScore":"Credit_Score",
    "Geography":"Country",
    "Gender":"Sex",
    "EstimatedSalary":"Salary",
    "Exited":"Target"
}, inplace=True)
df.head()
# Out:
#    Row_No  Customer_ID Last_Name  Credit_Score Country     Sex   Age  Tenure  \
# 0       1     15634602  Hargrave           619  France  Female  42.0       2
# 1       2     15647311      Hill           608   Spain  Female  41.0       1
# 2       3     15619304      Onio           502  France  Female  42.0       8
# 3       4     15701354      Boni           699  France  Female  39.0       1
# 4       5     15737888  Mitchell           850   Spain  Female  43.0       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary Target
# 0       0.00              1          1               1  101348.88      1
# 1   83807.86              1          0               1  112542.58      0
# 2  159660.80              3          1               0  113931.57      1
# 3       0.00              2          0               0   93826.63      0
# 4  125510.82              1          1               1   79084.10      0

# %% [markdown]
# ##### Q22 Create a new DataFrame that contains only numeric columns.
# ##### Then generate its statistical summary.

# %%
num_df =df.select_dtypes(include="number")
num_df.describe()
# Out:
#             Row_No   Customer_ID  Credit_Score           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# ##### Q23 Your company received duplicate customer records.
# ##### Tasks:
# ##### • Count duplicates.
# ##### • Remove duplicates.
# ##### • Display dataset information after cleaning.

# %%
df_count=df.duplicated().sum()
print("Total number duplicates row=",df_count)
print()
df_count=df.drop_duplicates()

df_count
print()
df_count.info()
# Out:
# Total number duplicates row= 0
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row_No          10000 non-null  int64
#  1   Customer_ID     10000 non-null  int64
#  2   Last_Name       10000 non-null  object
#  3   Credit_Score    10000 non-null  int64
#  4   Country         10000 non-null  object
#  5   Sex             10000 non-null  object
#  6   Age             10000 non-null  float64
#  7   Tenure          10000 non-null  int64
#  8   Balance         10000 non-null  float64
#  9   NumOfProducts   10000 non-null  int64
#  10  HasCrCard       10000 non-null  int64
#  11  IsActiveMember  10000 non-null  int64
#  12  Salary          10000 non-null  float64
#  13  Target          10000 non-null  object
# dtypes: float64(3), int64(7), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# ##### • Display dataset information after cleaning.
# #####
# ##### Q24
# ##### Management wants every column name to begin with
# ##### Customer_
# ##### Apply this transformation using the appropriate method.

# %%
df.add_prefix("Customer_")
# Out:
#       Customer_Row_No  Customer_Customer_ID Customer_Last_Name  \
# 0                   1              15634602           Hargrave
# 1                   2              15647311               Hill
# 2                   3              15619304               Onio
# 3                   4              15701354               Boni
# 4                   5              15737888           Mitchell
# ...               ...                   ...                ...
# 9995             9996              15606229           Obijiaku
# 9996             9997              15569892          Johnstone
# 9997             9998              15584532                Liu
# 9998             9999              15682355          Sabbatini
# 9999            10000              15628319             Walker
#
#       Customer_Credit_Score Customer_Country Customer_Sex  Customer_Age  \
# 0                       619           France       Female          42.0
# ...

# %% [markdown]
# ##### Q25
# ##### After renaming the columns, convert
# ##### Age
# ##### Balance
# ##### Salary
# ##### to float datatype.
# ##### Print dataset information.

# %%
df_re=df.rename(columns={"Age":"age","Balance":"balance","Salary":"salary"})
df_re.astype({"age":float,"balance":float,"salary":float})
# Out:
#       Row_No  Customer_ID  Last_Name  Credit_Score  Country     Sex   age  \
# 0          1     15634602   Hargrave           619   France  Female  42.0
# 1          2     15647311       Hill           608    Spain  Female  41.0
# 2          3     15619304       Onio           502   France  Female  42.0
# 3          4     15701354       Boni           699   France  Female  39.0
# 4          5     15737888   Mitchell           850    Spain  Female  43.0
# ...      ...          ...        ...           ...      ...     ...   ...
# 9995    9996     15606229   Obijiaku           771   France    Male  39.0
# 9996    9997     15569892  Johnstone           516   France    Male  35.0
# 9997    9998     15584532        Liu           709   France  Female  36.0
# 9998    9999     15682355  Sabbatini           772  Germany    Male  42.0
# 9999   10000     15628319     Walker           792   France  Female  28.0
#
#       Tenure    balance  NumOfProducts  HasCrCard  IsActiveMember     salary  \
# ...

# %% [markdown]
# ###### Q26 Assume CreditScore contains missing values.
# ###### Replace them with the median CreditScore.

# %%
df["Credit_Score"]=(df["Credit_Score"].fillna(df["Credit_Score"].median()))
df["Credit_Score"]
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: Credit_Score, Length: 10000, dtype: int64

# %% [markdown]
# ##### Q27 Assume EstimatedSalary contains missing values.
# ##### Replace them with the mean salary.
# ##### Then print the first eight rows.

# %%
df["Salary"]=(df["Salary"].fillna(df["Salary"].mean()))
df["Salary"].head(8)
# Out:
# 0    101348.88
# 1    112542.58
# 2    113931.57
# 3     93826.63
# 4     79084.10
# 5    149756.71
# 6     10062.80
# 7    119346.88
# Name: Salary, dtype: float64

# %% [markdown]
# ##### Q28 (Data Cleaning Challenge)
# ##### Perform all the following:
# ##### • Remove duplicate rows.
# ##### • Rename Exited to Target.
# ##### • Convert Target to string.
# ##### • Display dataset information.

# %%
df_remove=df.drop_duplicates()
df_rename=df_remove.rename(columns={"Exited":"Target"})
df_typechange=df_rename["Target"].astype(str)
df_typechange
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Target, Length: 10000, dtype: object

# %% [markdown]
# ##### Q29 (Transformation Challenge)
# ##### Create a copy of the dataset.
# ##### Perform these transformations:
# ##### • Rename Gender to CustomerGender
# ##### • Rename Geography to Country
# ##### • Add prefix Bank_
# ##### • Remove RowNumber
# ##### • Display first 10 rows

# %%
df_copy=df.copy()

# %%
df_copy.rename(columns={
    "Geography":"Country",
    "Gender":"CustomerGender",
}, inplace=True)
df_copy
# Out:
#       Row_No  Customer_ID  Last_Name  Credit_Score  Country     Sex   Age  \
# 0          1     15634602   Hargrave           619   France  Female  42.0
# 1          2     15647311       Hill           608    Spain  Female  41.0
# 2          3     15619304       Onio           502   France  Female  42.0
# 3          4     15701354       Boni           699   France  Female  39.0
# 4          5     15737888   Mitchell           850    Spain  Female  43.0
# ...      ...          ...        ...           ...      ...     ...   ...
# 9995    9996     15606229   Obijiaku           771   France    Male  39.0
# 9996    9997     15569892  Johnstone           516   France    Male  35.0
# 9997    9998     15584532        Liu           709   France  Female  36.0
# 9998    9999     15682355  Sabbatini           772  Germany    Male  42.0
# 9999   10000     15628319     Walker           792   France  Female  28.0
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  \
# ...

# %%
df_copy.add_prefix("Bank_")
# Out:
#       Bank_Row_No  Bank_Customer_ID Bank_Last_Name  Bank_Credit_Score  \
# 0               1          15634602       Hargrave                619
# 1               2          15647311           Hill                608
# 2               3          15619304           Onio                502
# 3               4          15701354           Boni                699
# 4               5          15737888       Mitchell                850
# ...           ...               ...            ...                ...
# 9995         9996          15606229       Obijiaku                771
# 9996         9997          15569892      Johnstone                516
# 9997         9998          15584532            Liu                709
# 9998         9999          15682355      Sabbatini                772
# 9999        10000          15628319         Walker                792
#
#      Bank_Country Bank_Sex  Bank_Age  Bank_Tenure  Bank_Balance  \
# ...

# %%
df_copy.drop(columns=["Row_No"],inplace=True)

# %%
df_copy.columns.tolist()
# Out:
# ['Customer_ID',
#  'Last_Name',
#  'Credit_Score',
#  'Country',
#  'Sex',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'Salary',
#  'Target']

# %%
df_copy.head(10)
# Out:
#    Customer_ID Last_Name  Credit_Score  Country     Sex   Age  Tenure  \
# 0     15634602  Hargrave           619   France  Female  42.0       2
# 1     15647311      Hill           608    Spain  Female  41.0       1
# 2     15619304      Onio           502   France  Female  42.0       8
# 3     15701354      Boni           699   France  Female  39.0       1
# 4     15737888  Mitchell           850    Spain  Female  43.0       2
# 5     15574012       Chu           645    Spain    Male  44.0       8
# 6     15592531  Bartlett           822   France    Male  50.0       7
# 7     15656148    Obinna           376  Germany  Female  29.0       4
# 8     15792365        He           501   France    Male  44.0       4
# 9     15592389        H?           684   France    Male  27.0       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary Target
# 0       0.00              1          1               1  101348.88      1
# ...

# %% [markdown]
# ##### Q30 Real Industry Mini Project
# ##### Your manager asks you to prepare a cleaned dataset for the Machine Learning team.
# ##### Perform all of these steps:
# ##### 1. Load the dataset.
# ##### 2. Display dataset information.
# ##### 3. Check missing values.
# ##### 4. Remove duplicate rows.
# ##### 5. Rename the following columns:
# ##### o CustomerId → Customer_ID
# ##### o CreditScore → Credit_Score
# ##### o EstimatedSalary → Salary
# ##### o Exited → Target
# ##### 6. Convert:
# ##### o Age → float
# ##### o Balance → float
# ##### o Target → string
# ##### 7. Replace missing values:
# ##### o Age → median
# ##### o Balance → mean
# ##### 8. Remove:
# ##### o RowNumber
# #####
# ##### Sumit Sir Notes
# ##### o Surname
# ##### 9. Display:
# ##### o First 10 rows
# ##### o Statistical summary
# ##### o Value counts of Target
# ##### o Final dataset information

# %% [markdown]
# ##### 1. Load the dataset.

# %%
import pandas as pd
df = pd.read_csv("C:/Users/hp/Downloads/Bank_customer_churn - Bank_customer_churn.csv")

# %% [markdown]
# ##### 2. Display dataset information.

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ##### 3. Check missing values.

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ##### 4. Remove duplicate rows.

# %%
df.drop_duplicates()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ##### 5. Rename the following columns:
# ##### o CustomerId → Customer_ID
# ##### o CreditScore → Credit_Score
# ##### o EstimatedSalary → Salary
# ##### o Exited → Target

# %%
df.rename(columns={
    "CustomerId":"Customer_ID",
    "CreditScore":"Credit_Score",
    "EstimatedSalary":"Salary",
    "Exited":"Target"
},inplace=True)

# %% [markdown]
# ##### 6. Convert:
# ##### o Age → float
# ##### o Balance → float
# ##### o Target → string

# %%
df.astype({"Age":float,"Balance":float,"Target":float})
# Out:
#       RowNumber  Customer_ID    Surname  Credit_Score Geography  Gender   Age  \
# 0             1     15634602   Hargrave           619    France  Female  42.0
# 1             2     15647311       Hill           608     Spain  Female  41.0
# 2             3     15619304       Onio           502    France  Female  42.0
# 3             4     15701354       Boni           699    France  Female  39.0
# 4             5     15737888   Mitchell           850     Spain  Female  43.0
# ...         ...          ...        ...           ...       ...     ...   ...
# 9995       9996     15606229   Obijiaku           771    France    Male  39.0
# 9996       9997     15569892  Johnstone           516    France    Male  35.0
# 9997       9998     15584532        Liu           709    France  Female  36.0
# 9998       9999     15682355  Sabbatini           772   Germany    Male  42.0
# 9999      10000     15628319     Walker           792    France  Female  28.0
#
# ...

# %% [markdown]
# ##### 7. Replace missing values:
# ##### o Age → median
# ##### o Balance → mean

# %%
print(df["Age"].fillna(df["Age"].median()))
print()
print(df["Balance"].fillna(df["Balance"].mean()))
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64
#
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %% [markdown]
# ##### 8. Remove:
# ##### o RowNumber
# ##### o Surname

# %%
df.drop(columns=["RowNumber","Surname"])
# Out:
#       Customer_ID  Credit_Score Geography  Gender  Age  Tenure    Balance  \
# 0        15634602           619    France  Female   42       2       0.00
# 1        15647311           608     Spain  Female   41       1   83807.86
# 2        15619304           502    France  Female   42       8  159660.80
# 3        15701354           699    France  Female   39       1       0.00
# 4        15737888           850     Spain  Female   43       2  125510.82
# ...           ...           ...       ...     ...  ...     ...        ...
# 9995     15606229           771    France    Male   39       5       0.00
# 9996     15569892           516    France    Male   35      10   57369.61
# 9997     15584532           709    France  Female   36       7       0.00
# 9998     15682355           772   Germany    Male   42       3   75075.31
# 9999     15628319           792    France  Female   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember     Salary  Target
# ...

# %% [markdown]
# ##### 9. Display:
# ##### o First 10 rows
# ##### o Statistical summary
# ##### o Value counts of Target
# ##### o Final dataset information

# %%
df.head(10)
# Out:
#    RowNumber  Customer_ID   Surname  Credit_Score Geography  Gender  Age  \
# 0          1     15634602  Hargrave           619    France  Female   42
# 1          2     15647311      Hill           608     Spain  Female   41
# 2          3     15619304      Onio           502    France  Female   42
# 3          4     15701354      Boni           699    France  Female   39
# 4          5     15737888  Mitchell           850     Spain  Female   43
# 5          6     15574012       Chu           645     Spain    Male   44
# 6          7     15592531  Bartlett           822    France    Male   50
# 7          8     15656148    Obinna           376   Germany  Female   29
# 8          9     15792365        He           501    France    Male   44
# 9         10     15592389        H?           684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  \
# 0       2       0.00              1          1               1  101348.88
# ...

# %%
df.describe()
# Out:
#          RowNumber   Customer_ID  Credit_Score           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df["Target"].value_counts()
# Out:
# Target
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df
# Out:
#       RowNumber  Customer_ID    Surname  Credit_Score Geography  Gender  Age  \
# 0             1     15634602   Hargrave           619    France  Female   42
# 1             2     15647311       Hill           608     Spain  Female   41
# 2             3     15619304       Onio           502    France  Female   42
# 3             4     15701354       Boni           699    France  Female   39
# 4             5     15737888   Mitchell           850     Spain  Female   43
# ...         ...          ...        ...           ...       ...     ...  ...
# 9995       9996     15606229   Obijiaku           771    France    Male   39
# 9996       9997     15569892  Johnstone           516    France    Male   35
# 9997       9998     15584532        Liu           709    France  Female   36
# 9998       9999     15682355  Sabbatini           772   Germany    Male   42
# 9999      10000     15628319     Walker           792    France  Female   28
#
# ...

# %% [markdown]
# ##### Bonus Challenge (Create New Columns)
# ##### These require creating new columns using basic Pandas assignment along with the methods
# ##### you've learned.
# ##### B1 Create a new column: TotalMoney = Balance + EstimatedSalary

# %%
df["TotalMoney"]=df["Balance"]+df["Salary"]

# %%
df.head()
# Out:
#    RowNumber  Customer_ID   Surname  Credit_Score Geography  Gender  Age  \
# 0          1     15634602  Hargrave           619    France  Female   42
# 1          2     15647311      Hill           608     Spain  Female   41
# 2          3     15619304      Onio           502    France  Female   42
# 3          4     15701354      Boni           699    France  Female   39
# 4          5     15737888  Mitchell           850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  \
# 0       2       0.00              1          1               1  101348.88
# 1       1   83807.86              1          0               1  112542.58
# 2       8  159660.80              3          1               0  113931.57
# 3       1       0.00              2          0               0   93826.63
# 4       2  125510.82              1          1               1   79084.10
#
#    Target  TotalMoney  DoubleScore
# 0       1   101348.88         1238
# ...

# %% [markdown]
# ##### B2 Create a new column: DoubleScore = CreditScore × 2

# %%
df["DoubleScore"]=df["Credit_Score"]*2

# %%
df.head()
# Out:
#    RowNumber  Customer_ID   Surname  Credit_Score Geography  Gender  Age  \
# 0          1     15634602  Hargrave           619    France  Female   42
# 1          2     15647311      Hill           608     Spain  Female   41
# 2          3     15619304      Onio           502    France  Female   42
# 3          4     15701354      Boni           699    France  Female   39
# 4          5     15737888  Mitchell           850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  \
# 0       2       0.00              1          1               1  101348.88
# 1       1   83807.86              1          0               1  112542.58
# 2       8  159660.80              3          1               0  113931.57
# 3       1       0.00              2          0               0   93826.63
# 4       2  125510.82              1          1               1   79084.10
#
#    Target  TotalMoney  DoubleScore
# 0       1   101348.88         1238
# ...

# %% [markdown]
# ##### B3 Create a new column: AgeAfter10Years = Age + 10

# %%
df["AgeAfter10Years"]=df["Age"]+10
df.head()
# Out:
#    RowNumber  Customer_ID   Surname  Credit_Score Geography  Gender  Age  \
# 0          1     15634602  Hargrave           619    France  Female   42
# 1          2     15647311      Hill           608     Spain  Female   41
# 2          3     15619304      Onio           502    France  Female   42
# 3          4     15701354      Boni           699    France  Female   39
# 4          5     15737888  Mitchell           850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  \
# 0       2       0.00              1          1               1  101348.88
# 1       1   83807.86              1          0               1  112542.58
# 2       8  159660.80              3          1               0  113931.57
# 3       1       0.00              2          0               0   93826.63
# 4       2  125510.82              1          1               1   79084.10
#
#    Target  TotalMoney  DoubleScore  AgeAfter10Years
# ...

# %% [markdown]
# ##### B4 Create a new column: HasBalance = Balance Replace missing values in this new column using the mean.

# %%
df["HasBalance"] = df["HasBalance"].fillna(df["HasBalance"].mean())
df.head()
# Out:
#    RowNumber  Customer_ID   Surname  Credit_Score Geography  Gender  Age  \
# 0          1     15634602  Hargrave           619    France  Female   42
# 1          2     15647311      Hill           608     Spain  Female   41
# 2          3     15619304      Onio           502    France  Female   42
# 3          4     15701354      Boni           699    France  Female   39
# 4          5     15737888  Mitchell           850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  \
# 0       2       0.00              1          1               1  101348.88
# 1       1   83807.86              1          0               1  112542.58
# 2       8  159660.80              3          1               0  113931.57
# 3       1       0.00              2          0               0   93826.63
# 4       2  125510.82              1          1               1   79084.10
#
#    Target  TotalMoney  DoubleScore  AgeAfter10Years  HasBalance
# ...

# %% [markdown]
# ##### B5 Create a new column: SalaryInLakhs = EstimatedSalary / 100000

# %%
df["SalaryInLakhs"] = df["Salary"] / 100000
df.head()
# Out:
#    RowNumber  Customer_ID   Surname  Credit_Score Geography  Gender  Age  \
# 0          1     15634602  Hargrave           619    France  Female   42
# 1          2     15647311      Hill           608     Spain  Female   41
# 2          3     15619304      Onio           502    France  Female   42
# 3          4     15701354      Boni           699    France  Female   39
# 4          5     15737888  Mitchell           850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember     Salary  \
# 0       2       0.00              1          1               1  101348.88
# 1       1   83807.86              1          0               1  112542.58
# 2       8  159660.80              3          1               0  113931.57
# 3       1       0.00              2          0               0   93826.63
# 4       2  125510.82              1          1               1   79084.10
#
#    Target  TotalMoney  DoubleScore  AgeAfter10Years  HasBalance  SalaryInLakhs
# ...
