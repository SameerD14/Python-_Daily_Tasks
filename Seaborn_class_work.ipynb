# %%
# import required lib
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
tips=sns.load_dataset("tips")
iris=sns.load_dataset("iris")
titanic=sns.load_dataset("titanic")
penguins=sns.load_dataset("penguins")
flights=sns.load_dataset("flights")
sns.set_theme(style="whitegrid",palette="bright",font_scale=1.1)
# catplot() funtion part 1
# make the simple catplot
sns.catplot(data=tips,x="day",y="total_bill",kind="boxen")

# %%
# make the all plots
# create 2*4 grid
#make the all plots

#create 2x4 grid
fig,axes=plt.subplots(2,4,figsize=(20,10))

#title of figure
fig.suptitle("Categorical Plots - All 8 Types",
             fontsize=18,
             fontweight="bold")

axes=axes.flatten()

#strip plot
sns.stripplot(data=tips,
             x = "day",
             y = "total_bill",
             hue = "sex",
             palette = "dark",
              ax=axes[0])

sns.barplot(data=tips,
             x = "day",
             y = "total_bill",
             hue = "sex",
             palette = "dark",
              ax=axes[1])

sns.boxplot(data=tips,
             x = "day",
             y = "total_bill",
             hue = "sex",
             palette = "dark",
              ax=axes[2])

sns.violinplot(data=tips,
             x = "day",
             y = "total_bill",
             hue = "sex",
             palette = "dark",
              ax=axes[3])

sns.pointplot(data=tips,
             x = "day",
             y = "total_bill",
             hue = "sex",
             palette = "dark",
              ax=axes[4])

sns.boxenplot(data=tips,
             x = "day",
             y = "total_bill",
             hue = "sex",
             palette = "dark",
              ax=axes[5])

sns.countplot(data=tips,
             x = "day",
           
             hue = "sex",
             palette = "dark",
              ax=axes[6])

sns.pointplot(data=tips,
             x = "day",
             y = "total_bill",
             hue = "sex",
             palette = "dark",
              ax=axes[7])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips,x="data",y="total_bill",hue="size",col="time",palette=["blue","red"],height=5,aspect=0.9,linewidth=l.5)
# Out:
#   Cell In[22], line 1
#     sns.catplot(data=tips,x="data",y="total_bill",hue="size",col="time",palette=["blue","red"],height=5,aspect=0.9,linewidth=l.5)
#                                                                                                                              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
