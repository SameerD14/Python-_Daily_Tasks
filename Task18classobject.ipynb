# %% [markdown]
# #### Basic Class & Object (1-8)
# ##### 1. Create a class Student with instance attributes name and age. Create two objects and print their details.

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def details(self):
        print("Name =",self.name)
        print("Age =",self.age)
std1=Student("Sumit",27)
print("Name=",std1.name)
print("Age=",std1.age)

std1.details()
# Out:
# Name= Sumit
# Age= 27
# Name = Sumit
# Age = 27

# %% [markdown]
# ##### 2. Define class Car with attributes brand, model, and year. Create an object and display all attributes.

# %%
class Car:
    def __init__(self,brand,model,year):
        self.brand=brand
        self.model=model
        self.year=year
    def display(self):
        print("Car name = ",self.brand)
        print("Model no =",self.model)
        print("Year =",self.year)
car1=Car("BMW",3634643,2007)
car1.display()
# Out:
# Car name =  BMW
# Model no = 3634643
# Year = 2007

# %% [markdown]
# ##### 3. Create class Book with attributes title, author, price. Add a method display_info().

# %%
class Book:
    def __init__(self,title,author,price):
        self.title=title
        self.author=author
        self.price=price
    def display_info(self):
        print("Book Name=",self.title)
        print("Author Name=",self.author)
        print("Price =",self.price)
book1=Book("Wings of fire","Dr.A.P.J.Abdul Kalam",900)
book2=Book("Discovery of India","Pandit jawarlal Nehru",800)
book1.display_info()
print("*" *40)
book2.display_info()
# Out:
# Book Name= Wings of fire
# Author Name= Dr.A.P.J.Abdul Kalam
# Price = 900
# ****************************************
# Book Name= Discovery of India
# Author Name= Pandit jawarlal Nehru
# Price = 800

# %% [markdown]
# ##### 4. Create class Employee with attributes emp_id, name, salary. Create 3 objects.

# %%
class Employees:
    def __init__(self, emp_id, name, salary):
        self.emp_id=emp_id
        self.name=name
        self.salary=salary

    def display_info(self):
        print("Emp_id=",self.emp_id)
        print("Name=",self.name)
        print("Salary=",self.salary)
        print("--------"*5)
emp1=Employees(101, "sameer", 10000)
emp1.display_info()

emp2=Employees(102, "yash", 11000)
emp2.display_info()

emp3=Employees(103, "sahil", 10500)
emp3.display_info()
# Out:
# Emp_id= 101
# Name= sameer
# Salary= 10000
# ----------------------------------------
# Emp_id= 102
# Name= yash
# Salary= 11000
# ----------------------------------------
# Emp_id= 103
# Name= sahil
# Salary= 10500
# ----------------------------------------

# %% [markdown]
# ##### 5. Write a class Mobile with attributes brand, price, color. Print object using __str__ method.

# %%
class Mobile:
    def __init__(self,brand,color,price):
        self.brand=brand
        self.color=color
        self.price=price
        
    def __str__(self):
        return f"Mobile Brand {self.brand} \nMobile color {self.color} \nMobile Price {self.price}"

mobile1 = Mobile("Samsung","Black",20000)
mobile2 = Mobile("Samsung","Black",82000)
print(mobile1)

print("*"*50)
print(mobile2)
# Out:
# Mobile Brand Samsung
# Mobile color Black
# Mobile Price 20000
# **************************************************
# Mobile Brand Samsung
# Mobile color Black
# Mobile Price 82000

# %% [markdown]
# ##### 6. Create class Rectangle with attributes length and width. Add method to calculate area.

# %%
class Rectraingle:
     def __init__(self,length,width):
         self.length=length
         self.width=width
     def Area(self):
        area=self.length*self.width
        print("Area of Rectrainge=",area)
area1=Rectraingle(4,9)
area1.Area()
# Out:
# Area of Rectrainge= 36

# %% [markdown]
# ##### 7. Define class Person with attributes name and city. Create object and change city value.

# %%
class Person:
     def __init__(self,name,city):
         self.name=name
         self.city=city
     def display_info(self):
         print("Name=",self.name)
         print("City=",self.city)
     def change(self,new_city):
         self.city=new_city
         print("Name=",self.name)
         print("City=",self.city)
person1=Person("Sameer","hyderabad")
person1.display_info()
print("#"*80)
person1.change("mumbai")
# Out:
# Name= Sameer
# City= hyderabad
# ################################################################################
# Name= Sameer
# City= mumbai

# %% [markdown]
# ##### 8. Create class Laptop and show how to create multiple objects with different values.

# %%
class Laptop:
    def __init__(self,name,brand,model,price):
        self.name=name
        self.brand=brand
        self.model=model
        self.price=price
    def display(self):
        print("Laptop name=",self.name)
        print("Laptop Brand=",self.brand)
        print("Laptop Model=",self.model)
        print("Laptop Price=",self.price)
laptop1=Laptop("Hp-Victus","HP",98767,89000)
laptop1.display()
print()
laptop2=Laptop("Asus Tuf gaming","Asus",98755,69000)
laptop2.display()
# Out:
# Laptop name= Hp-Victus
# Laptop Brand= HP
# Laptop Model= 98767
# Laptop Price= 89000
#
# Laptop name= Asus Tuf gaming
# Laptop Brand= Asus
# Laptop Model= 98755
# Laptop Price= 69000

# %% [markdown]
# #### Class Attributes (9-15)
# ##### 9. Create class Student with class attribute school_name = "City School". Print it using class name and object.

# %%
class Student:
    school_name="City School"
    def __init__(self,name,id,class_name):
        self.name=name
        self.id=id
        self.class_name=class_name
    def std_info(self):
        print("School Name=",Student.school_name)
        print("Name=",self.name)
        print("Id=",self.id)
        print("Class No=",self.class_name)
print(Student.school_name)
print()
std1=Student("Sameer",18,"12 th")
std2=Student("Piyush",16,"11 th")
std1.std_info()
print()
std2.std_info()
# Out:
# City School
#
# School Name= City School
# Name= Sameer
# Id= 18
# Class No= 12 th
#
# School Name= City School
# Name= Piyush
# Id= 16
# Class No= 11 th

# %% [markdown]
# ##### 10. Create class Bank with class attribute bank_name. Change its value using class name and check effect on objects.

# %%
#Answer 1
class Bank:
    bank_name = "Punjab National Bank"
# Create Objects
bank1 = Bank()
bank2 = Bank()
print("Before Changing")
print(bank1.bank_name)
print(bank2.bank_name)
# Change using class name
Bank.bank_name = "State Bank Of India"
print("\nAfter Changing")
print(bank1.bank_name)
print(bank2.bank_name)
# Answer 2
class Bank:
    Bank_name="Punjab National Bank"
    @classmethod
    def display_Bank_name(cls,new_name):
        cls.Bank_name=new_name
        print(f"Bank name= {cls.Bank_name}")
print(Bank.Bank_name)
bank1=Bank()
bank1.display_Bank_name("State Bank Of India")
# Out:
# Before Changing
# Punjab National Bank
# Punjab National Bank
#
# After Changing
# State Bank Of India
# State Bank Of India
# Punjab National Bank
# Bank name= State Bank Of India

# %% [markdown]
# ##### 11. Define class Counter with class attribute count = 0. Add method to increment count.

# %%
class Counter:
    count=0 # class object
    def increment(self):
        Counter.count+=1
        print("count=",Counter.count)
counter1=Counter()
counter1.increment()
counter2=Counter()
counter2.increment()
# Out:
# count= 1
# count= 2

# %% [markdown]
# ##### 12. Create class Employee with class attribute company = "ABC Corp". Show that all objects share it.

# %%
class Employee :
    company="ABC Corp"
    def __init__(self,name,age,salary):
        self.name=name
        self.age=age
        self.salary=salary
    def display_info(self):
        print("Company Name=",Employee.company)
        print("Employee name =",self.name)
        print("Age=",self.age)
        print("Salary=",self.salary)
emp1=Employee("Sameer",23,34500)
emp2=Employee("Amit",24,28900)
emp3=Employee("Piyush",25,29000)
emp1.display_info()
print("*"*50)
emp2.display_info()
print("*"*50)
emp3.display_info()
# Out:
# Company Name= ABC Corp
# Employee name = Sameer
# Age= 23
# Salary= 34500
# **************************************************
# Company Name= ABC Corp
# Employee name = Amit
# Age= 24
# Salary= 28900
# **************************************************
# Company Name= ABC Corp
# Employee name = Piyush
# Age= 25
# Salary= 29000

# %% [markdown]
# ##### 13. In class Circle, add class attribute pi = 3.14. Use it in area calculation method.

# %%
class Circle:
    pi=3.14
    def __init__(self,radius):
        self.radius=radius
    def Area(self):
        area=Circle.pi*self.radius**2
        print("Area of circle=",area)
circle1=Circle(5)
circle1.Area()
# Out:
# Area of circle= 78.5

# %% [markdown]
# ##### 14. Create class MathUtils with class attribute version = "1.0". Print it.

# %%
class MathUtils:
    version="1.0"
print(MathUtils.version)
mathsutil1=MathUtils()
print(mathsutil1.version)
# Out:
# 1.0
# 1.0

# %% [markdown]
# ##### 15. Show difference between class attribute and instance attribute with example of class Player.

# %%
class Player:
    team="India" # class Attribute It is common for all object
    def __init__(self,name,jersey_no):
        self.name=name   # Instande Attribute It is used for particular object
        self.jersey_no=jersey_no
    def display_info(self):
        print("Team=",Player.team)
        print("Player Name=",self.name)
        print("Age=",self.jersey_no)
player1=Player("Virat Kholi",18)
player2=Player("Rohit Sharma",45)
player3=Player("M.s Dhoni",7)
player1.display_info()
print("*"*50)
player2.display_info()
print("*"*50)
player3.display_info()
# Out:
# Team= India
# Player Name= Virat Kholi
# Age= 18
# **************************************************
# Team= India
# Player Name= Rohit Sharma
# Age= 45
# **************************************************
# Team= India
# Player Name= M.s Dhoni
# Age= 7

# %% [markdown]
# ##### Private Attributes (16-22)
# ##### 16. Create class BankAccount with private attribute __balance. Try to access it directly (show error).

# %%
class BankAccount:
    #class attribute
    bank_name="State Bank of India"
    # create constructor
    def __init__(self,ac_no,bla,branch):
        self.Account_number=ac_no
        self.__Balance=bla  #private attribute
        self.Branch=branch
    # display  the all attribute
    # method 1
    def get_balance(self): #getter
        return (self.__Balance)
    def display_bank_details(self):
        print("Account Number =",self.Account_number)
        print("Balance=",self.__Balance) 
        print("Branch=",self.Branch)
        print("Bank_name=",BankAccount.bank_name)
    # method 2 deposit money
    def deposit(self,amount):
        if amount>0:
            self.__Balance+=amount
            print(f"Deposit {self.__Balance} money successfully Done")
    # method 3 withdraw money
    def withdraw(self,amount):
        if amount<=0:
            print("Invalid amount")
        elif amount>self.__Balance:
            print("Insufficient balance")
        else:
            self.__Balance-=amount
            print(f"Withraw amount is {amount}")
            print(f"Balance is {self.__Balance}")
cst1=BankAccount(32432418,8000,"Ameerpet")
print("Balance is ",cst1.get_balance()) #private attribute access
cst1.display_bank_details() 

cst1.deposit(6000)
cst1.withdraw(9000)
print("#"*40)
cst1=BankAccount(32489410,8000,"Charminar")
cst1.display_bank_details()
cst1.deposit(8000)
cst1.withdraw(5000)
# Out:
# Balance is  8000
# Account Number = 32432418
# Balance= 8000
# Branch= Ameerpet
# Bank_name= State Bank of India
# Deposit 14000 money successfully Done
# Withraw amount is 9000
# Balance is 5000
# ########################################
# Account Number = 32489410
# Balance= 8000
# Branch= Charminar
# Bank_name= State Bank of India
# Deposit 16000 money successfully Done
# Withraw amount is 5000
# Balance is 11000

# %% [markdown]
# ##### 17. Define class Student with private attribute __marks. Print it using name mangling.

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.__marks=marks
    def get_marks(self):
        return self.__marks
std1=Student("Sameer",90)
print("Name=",std1.name)
# Access using Name Mangling
print("Marks=",std1._Student__marks)
# By Accessing getter
print("Marks=",std1.get_marks())
# Out:
# Name= Sameer
# Marks= 90
# Marks= 90

# %% [markdown]
# ##### 18. Create class Employee with private __salary. Show how it becomes _ClassName__salary.

# %%
class Employee :
    def __init__(self,name,salary):
        self.name=name
        self.__salary=salary
    def display_info(self):
        print("Name=",self.name)
        print("Salary=",self._Employee__salary)
emp1=Employee("Sameer",70977)
print("Name =", emp1.name)
print("Salary =", emp1._Employee__salary)
emp2=Employee("Amit",67839)
print("#"*40)

emp1.display_info()
print("#"*40)
print("Name =", emp2.name)
print("Salary =", emp2._Employee__salary)
print("#"*40)

emp2.display_info()
# Out:
# Name = Sameer
# Salary = 70977
# ########################################
# Name= Sameer
# Salary= 70977
# ########################################
# Name = Amit
# Salary = 67839
# ########################################
# Name= Amit
# Salary= 67839

# %% [markdown]
# ##### 19. In class Product, make __price private. Try accessing from outside.

# %%
class Product:
    def __init__(self,name,price):
        self.name=name
        self.__price=price
    def get_price(self):
        return self.__price
product1=Product("HP Victus",90000)
product2=Product("Asus Tuf gaming",78000)
print(product1.name)
print(product1.get_price())
print("*"*50)
print(product2.name)
print(product2.get_price())
# Out:
# HP Victus
# 90000
# **************************************************
# Asus Tuf gaming
# 78000

# %% [markdown]
# ##### 20. Create class User with private __password. Demonstrate name mangling.

# %%
class User:
    def __init__(self,username,password):
        self.username=username
        self.__password=password
user1=User("Sameer@13","safas")
user2=User("Sumit@834","sqrr")
print("Username=",user1.username)
print("Password=",user1._User__password)
print("*"*60)
print("Username=",user2.username)
print("Password=",user2._User__password)
# Out:
# Username= Sameer@13
# Password= safas
# ************************************************************
# Username= Sumit@834
# Password= sqrr

# %% [markdown]
# ##### 21. Define class Car with private attributes __model and __year.

# %%
class Car:
    def __init__(self,brand,model,year):
        self.brand=brand
        self.__model=model
        self.__year=year
    def get_model_display(self):
        return self.__model
    def get_year_display(self):
        return self.__year
    def display(self):
        print("Car name = ",self.brand)
        print("Model no =",self._Car__model)
        print("Year =",self._Car__year)
car1=Car("BMW",3634643,2007)
print("Model no =",car1.get_model_display())
print("Year =",car1.get_year_display())
print("*"*60)
car1.display()
# Out:
# Model no = 3634643
# Year = 2007
# ************************************************************
# Car name =  BMW
# Model no = 3634643
# Year = 2007

# %% [markdown]
# ##### 22. Create class Account with private __account_number.

# %%
class Account :
    bank_name="State Bank of India"
    # create constructor
    def __init__(self,ac_no,bla):
        self.__Account_number=ac_no
        self.__Balance=bla  #private attribute
    def get_acc_no(self):
        return self.__Account_number
    def get_balance(self):
        return self.__Balance
print("Bank Name=",Account.bank_name)
user1=Account(3523532,79000)
print("Account No=",user1.get_acc_no())
print("Balance=",user1.get_balance())
print("*"*90)
print("Bank Name=",Account.bank_name)
user2=Account(352097,68900)
print("Account No=",user2.get_acc_no())
print("Balance=",user2.get_balance())
# Out:
# Bank Name= State Bank of India
# Account No= 3523532
# Balance= 79000
# ******************************************************************************************
# Bank Name= State Bank of India
# Account No= 352097
# Balance= 68900

# %% [markdown]
# ##### Getter and Setter (23-30)
# ##### 23. Create class Student with private __marks. Add getter and setter methods.

# %%
class Student:
    def __init__(self,name):
        self.name=name
        self.__marks=78
    def set_marks(self,new_marks):
        if 0<=self.__marks<=100:
            self.__marks=new_marks
        else:
            print("Invalid marks")
    def get_marks(self):
        return self.__marks
s=Student("sameer")
print(s.name)
s.set_marks(88)
print(s.get_marks())
# Out:
# sameer
# 88

# %% [markdown]
# ##### 24. In class BankAccount, add getter and setter for private __balance with validation.

# %%
class BankAccount:
    def __init__(self,acc_no):
        self.acc_no=acc_no
        self.__balance=7000
    def set_balance(self,new_balance):
        if 0<new_balance:
            self.__balance=new_balance
        else:
            print("Invalid amount")
    def get_balance(self):
        return self.__balance
bank1=BankAccount(878787)
bank1.set_balance(8000)
print("Account no=",bank1.acc_no)
print("Balance=",bank1.get_balance())
print("*"*90)
bank2=BankAccount(95022)
bank2.set_balance(60400)
print("Account no=",bank2.acc_no)
print("Balance=",bank2.get_balance())
# Out:
# Account no= 878787
# Balance= 8000
# ******************************************************************************************
# Account no= 95022
# Balance= 60400

# %% [markdown]
# ##### 25. Create class Employee with private __salary. Setter should not allow value below 5000.

# %%
class Employee:
    def __init__(self,name):
        self.name=name
        self.__salary=10000
    def set_salary(self,new_salary):
        if new_salary>5000:
           self.__salary=new_salary
        else:
            print("Invalid salary")
    def get_salary(self):
        return self.__salary
emp1=Employee("Amit")
emp1.set_salary(59000)
print("Name=",emp1.name)
print("Salary=",emp1.get_salary())
print("*"*90)
emp1=Employee("Sameer")
emp1.set_salary(67000)
print("Name=",emp1.name)
print("Salary=",emp1.get_salary())
# Out:
# Name= Amit
# Salary= 59000
# ******************************************************************************************
# Name= Sameer
# Salary= 67000

# %% [markdown]
# ##### 26. Define class Temperature with private __celsius. Add getter and setter with conversion.

# %%
class Temperature:
    def __init__(self,celsius):
        self.__celsius=celsius
    def get_celsius(self):
        return self.__celsius
    def set_celsius(self,new_celsius):
        self.__celsius=new_celsius
    def to_fahrenheit(self):
        fahrenheit=(self.__celsius*9/5)+32
        return fahrenheit
temp1=Temperature(45)
print("Temperature=",temp1.get_celsius())
print("*"*70)
temp1.set_celsius(39)
print("Temperature=",temp1.get_celsius())
print("conversion in fahrenheit=",temp1.to_fahrenheit())
# Out:
# Temperature= 45
# **********************************************************************
# Temperature= 39
# conversion in fahrenheit= 102.2

# %% [markdown]
# ##### 27. Create class Person with private __age. Add setter with validation (age between 0-120).

# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.__age=20
    def set_age(self,new_age):
        if 0<new_age<120:
            self.__age=new_age
        else:
            print("Invalid Age")
    def get_age(self):
        return (self.__age)
        
user1=Person("Sameer",24)
user1.set_age(22)
print("Name=",user1.name)
print("Age=",user1.get_age())
# Out:
# Name= Sameer
# Age= 22

# %% [markdown]
# ##### 28. In class Product, add getter and setter for private __price with discount logic.

# %%
class Product:
    def __init__(self,name,price):
        self.name=name
        self.__price=price
    def get_price(self):
        return self.__price
    def set_price(self):
        if self.__price>5000:
            discount=self.__price*10/100
            self.__price-=discount
        else:
            discount=self.__price*5/100
            self.__price-=discount
        return self.__price
product1=Product("HP Victus",90000)
product2=Product("Asus Tuf gaming",78000)
print(product1.name)
print(product1.get_price())
print("*"*50)
print(product1.name)
print(product1.set_price())
print("*"*50)
print(product1.name)
print(product1.get_price())
print("*"*50)
print(product2.name)
print(product2.get_price())
print("*"*50)
print(product2.name)
print(product2.set_price())
# Out:
# HP Victus
# 90000
# **************************************************
# HP Victus
# 81000.0
# **************************************************
# HP Victus
# 81000.0
# **************************************************
# Asus Tuf gaming
# 78000
# **************************************************
# Asus Tuf gaming
# 70200.0

# %% [markdown]
# ##### 29. Create class Mobile with private __price. Add setter that prints message on price change.

# %%
class Mobile:
    def __init__(self,brand,price):
        self.brand=brand
        self.__price=price
    def get_previous_price(self):
        return self.__price
    def set_price(self,new_price):
        self.__price=new_price
    def get_new_price(self):
        return self.__price
    
mobile1 = Mobile("Samsung",20000)
print("Brand=",mobile1.brand)
print("Old Price=",mobile1.get_previous_price())
mobile1.set_price(15674)
print("New Price=",mobile1.get_new_price())
print("*"*50)
mobile2 = Mobile("Samsung",82000)
print("Brand=",mobile2.brand)
print("Old Price=",mobile2.get_previous_price())
mobile2.set_price(67500)
print("New Price=",mobile2.get_new_price())
# Out:
# Brand= Samsung
# Old Price= 20000
# New Price= 15674
# **************************************************
# Brand= Samsung
# Old Price= 82000
# New Price= 67500

# %% [markdown]
# ##### 30. Define class Rectangle with private __length and __width. Add getter/setter and area method.

# %%
class Rectraingle:
     def __init__(self):
         self.__length=0
         self.__width=0
     def set_length(self,length):
         self.__length=length
     def set_width(self,width):
         self.__width=width
     def get_length(self):
         return self.__length
     def get_width(self):
         return self.__width
     def Area(self):
        area=self.__length*self.__width
        print("Area of Rectrainge=",area)
area1=Rectraingle()
area1.set_length(13)
area1.set_width(8)
print("Length=",area1.get_length())
print("Width=",area1.get_width())
area1.Area()
# Out:
# Length= 13
# Width= 8
# Area of Rectrainge= 104
