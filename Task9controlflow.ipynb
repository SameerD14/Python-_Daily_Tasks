# %% [markdown]
# ##### 1. Write a program to check whether a number is positive, negative, or zero.

# %%
num=int(input("Enter a number="))
if num>0:
    print(f"{num} is Positive")
elif num<0:
    print(f"{num} is Negative")
else:
    print(f"{num} is Zero")
# Out:
# Enter a number= 0
# 0 is Zero

# %% [markdown]
# ##### 2. Write a program to check whether a person can enter a movie theater.(Age must be 18 or above)

# %%
age=int(input("Enter a age:"))
if age>=18:
    print("You can enter a movie theater..")
else:
    print("You can not enter a movie theater..")
# Out:
# Enter a age: 12
# You can not enter a movie theater..

# %% [markdown]
# ##### 3. Write a program to check whether a number is divisible by 2.

# %%
num=int(input("Enter a number: "))
if num%2==0:
    print(f"{num} is divisible by 2")
else:
    print(f"{num} is not divisible by 2")
# Out:
# Enter a number:  35
# 35 is not divisible by 2

# %% [markdown]
# ##### 4. Write a program to compare two numbers and print the greater number.

# %%
num1=float(input("Enter a number: "))
num2=float(input("Enter a number2: "))
if num1>num2:
    print(f"{num1} is greater than {num2}")
else:
        print(f"{num2} is greater than {num1}")
# Out:
# Enter a number:  34
# Enter a number2:  56
# 56.0 is greater than 34.0

# %% [markdown]
# ##### 5. Write a program to check whether a character is uppercase or lowercase.

# %%
ch=input("Enter a character: ")
if ch.isupper():
    print(f"{ch} in uppercase..")
elif ch.islower():
    print(f"{ch} in lowercase..")
else:
    print(f"{ch} is ot

# %% [markdown]
# ##### 6. Write a program to check whether a year is a leap year or not.

# %%
year=int(input("Enter a year: "))
if year%4==0 and year%100!=0 or year%400==0 :
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year:  1800
# Not a Leap Year

# %% [markdown]
# ##### 7. Write a program to display: o "Morning" if time < 12   o "Afternoon" if time between 12 and 5   o "Evening" otherwise

# %%
## time=int(input("Enter a time(0-23): "))
if time<12:
    print("Morning")
elif time>=12 and time<=17:
    print("Afternoon")
else:
    print("Evening")
# Out:
# Enter a time:  23
# Evening

# %% [markdown]
# ##### 8. Write a program to check whether a student passed with distinction.   o 75+ → Distinction    o 35–74 → Pass    o Below 35 → Fail

# %%
per=float(input("Enter a percentage: "))
if per>75:
    print("Passed with Distinction")
elif per<=75 and per>=35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter a percentage:  12
# Fail

# %% [markdown]
# ##### 1. Write a program to find the largest among three numbers.

# %%
num1=float(input("Enter a number1:"))
num2=float(input("Enter a number2:"))
num3=float(input("Enter a number3:"))
largest=num1
if num2>=largest:
    largest=num2
if num3>=largest:
    largest=num3
print("Largest Number is=",largest)
# Out:
# Enter a number1: 56
# Enter a number2: 23
# Enter a number3: 89
# Largest Number is= 89.0

# %% [markdown]
# ##### 2. Write a program to calculate electricity bill:  o Units < 100 → ₹2/unit   o 100–300 → ₹4/unit    o Above 300 → ₹6/unit

# %%
units=float(input("Enter a units: "))
if units<100:
    print("Electric Bill=",2*units)
elif units>=100 and units<=300:
    print("Electric Bill=",4*units)
else:
    print("Electric Bill=",6*units)
# Out:
# Enter a units:  100
# Electric Bill= 400.0

# %% [markdown]
# ##### 3. Write a program to check whether a triangle is:  o Equilateral  o Isosceles  o Scalene

# %%
a=int(input("Enter a side a =" ))
b=int(input("Enter a side b =" ))
c=int(input("Enter a side c =" ))
if a==b==c:
        print("Equilateral Traingle..")
elif a==b or b==c or a==c:
        print("Isoceles Traingle")
else:
        print("Scalene Traingle")
# Out:
# Enter a side a = 60
# Enter a side b = 60
# Enter a side c = 60
# Equilateral Traingle..

# %% [markdown]
# ##### Write a program to calculate a bonus o Salary > 50000 → 20% bonus   o Salary between 30000–50000 → 10% bonus   o Otherwise → 5% bonus

# %%
salary=int(input("Enter a salary: "))
if salary>50000:
    print("Bonus=",salary*20/100)
elif salary>=30000 and salary<=50000:
    print("Bonus=",salary*10/100)
else:
    print("Bonus=",salary*5/100)
# Out:
# Enter a salary:  30000
# Bonus= 3000.0

# %% [markdown]
# ##### 5. Write a program to check login credentials using username and password.

# %%
username=input("Enter a username=")
password=input("Enter a password=")
log_name=input("Enter a name=")
log_password=input("Enter a log password=")
if username==log_name and password==log_password:
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter a username= AMM
# Enter a password= 45
# Enter a name= AMM
# Enter a log password= 45
# Login Successful

# %% [markdown]
# ##### 6. Write a program to check whether a number is:  o Multiple of both 3 and 5  o Multiple of only 3   o Multiple of only 5   o None

# %%
num=int(input("Enter a number: "))
if num%5==0 and num%3==0:
    print("divisible 3 and 5")
elif num%3==0:
    print("divisible by 3")
elif num%5==0:
    print ("disible by 5")
else:
    print("not divisible by 3 and 5")
# Out:
# Enter a number:  45
# divisible 3 and 5

# %% [markdown]
# ##### 7. Write a program to find whether a person is: o Child (0–12)  o Teenager (13–19)  o Adult (20–59)  o Senior Citizen (60+)

# %%
age=int(input("Enter a age: "))
if age<=12:
    print("Child")
elif age>12 and age<=19:
    print("Teenager")
elif age>=20 and age<=59:
    print("Adult")
elif age>=60 and age<100:
    print("Senior Citizens")
else:
    print("Invalid age")
# Out:
# Enter a age:  110
# Invalid age

# %% [markdown]
# ##### 8. Write a program to calculate ticket price:  o Age below 5 → Free  o 5–18 → ₹100  o Adults → ₹200  o Senior citizens → ₹150

# %%
age=int(input("Enter a age: "))
if age<5:
    print("Ticket is free")
elif age>=5 and age<=18:
    print("Ticket is 100 ruppes")
elif age>18 and age<60:
    print("Ticket is 200 ruppes")
elif age>=60 and age<=100:
    print("Ticket is 150 ruppes")
else:
    print("INVALID AGE")
# Out:
# Enter a age:  112
# INVALID AGE

# %% [markdown]
# ##### 1. Write a program to create a simple ATM system:  o Check balance   o Withdraw money   o Deposit money   o Invalid option message

# %%
# check balance=1
# withdraw money=2
# deposit money=3
balance=5000
choice=int(input("Enter a choice: "))
if choice==1:
    print("Balance is ",balance)
elif choice==2:
     withdrawl=int(input("Enter a withdrwal money: "))
     if withdrawl>balance:
        print("Insufficinet Balance")
     else:
        print("Withdrawal Successful ",withdrawl)
        print("Balance amount is ",balance-withdrawl)
elif choice==3:
      deposit=int(input("Enter a deposit amount="))
      print("Balance is ",deposit+balance)

# %% [markdown]
# ##### 2. Write a program to calculate income tax:  o Income below ₹250000 → No tax   o ₹250000–₹500000 → 5%  o ₹500000–₹1000000 → 20%   o Above ₹1000000 → 30%

# %%
income=int(input("Enter a income: "))
if income <25000:
    print("No tax")
elif  income>=25000 and income<50000:
    print("Tax amount is ",income*5/100)
elif income>=50000 and income <100000 :
    print("Tax amount is ",income*20/100)
else:
    print("Tax amount is ",income*30/100)
# Out:
# Enter a income:  67000
# Tax amount is  13400.0

# %% [markdown]
# ##### 3. Write a program to determine the type of roots in a quadratic equation using discriminant.

# %%
a = float(input("Enter value of a: "))
b = float(input("Enter value of b: "))
c = float(input("Enter value of c: "))
d = b**2 - 4*a*c
if d>0:
    print("Two different real roots")
elif d==0:
    print("Two equal real roots")
else :
    print("Two complex roots")
# Out:
# Enter value of a:  34
# Enter value of b:  67
# Enter value of c:  89
# Two complex roots

# %% [markdown]
# ##### 4. Write a program for a mini calculator using if elif else: o Addition o Subtraction  o Multiplication  o Division

# %%
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter your choice: "))
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
if choice == 1:
    print("Answer =", num1 + num2)
elif choice == 2:
    print("Answer =", num1 - num2)
elif choice == 3:
    print("Answer =", num1 * num2)
elif choice == 4:
    if num2 != 0:
        print("Answer =", num1 / num2)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid Choice")
# Out:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice:  2
# Enter first number:  34
# Enter second number:  56
# Answer = -22.0

# %% [markdown]
# ##### 5. Write a program to check whether three angles can form a valid triangle.

# %%
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))
if(a+b>c)and(a+c>b)and(b+c>c):
    print("Valid Traingle>>>>")
else:
    print("Invalid Traingle....")
# Out:
# Enter first side:  56
# Enter second side:  78
# Enter third side:  89
# Valid Traingle>>>>

# %% [markdown]
# ##### 6. Write a program to determine the season based on month number.

# %%
month=int(input("Enter a month no: "))
if month>=3 and month<7:
    print("Summer season")
elif month>=7 and month<11:
    print("Rainy season")
elif month==11 or month==12 or( month>=1 and month<3):
    print("winter season")
else:
    print("Invalid choice")
# Out:
# Enter a month no:  12
# winter season

# %% [markdown]
# ##### 7. Write a program for an online shopping discount system:  o Purchase above ₹5000 → 30% discount  o ₹2000–₹5000 → 20% discount o Below ₹2000 → 10% discount

# %%
amount=int(input("Enter a shopping amount="))
if amount>5000:
    print("Discount is ",amount*30/100)
    print("You pay only ",amount-(amount*30/100))
elif amount>=2000 and amount<5000:
    print("Discount is ",amount*20/100)
    print("You pay only ",amount-(amount*20/100))
else:
    print("Discount is ",amount*10/100)
    print("You pay only ",amount-(amount*10/100))
# Out:
# Enter a shopping amount= 1000
# Discount is  100.0
# You pay only  900.0

# %% [markdown]
# ##### 8. Write a program to assign employee performance ratings:  o 90+ → Excellent  o 70–89 → Good    o 50–69 → Average  o Below 50 → Poor

# %%
attendance=int(input("Enter a Employee Attendance: "))
if attendance>=90 :
    print("Excellent")
    print("*"*5)
elif attendance>=70 and attendance<90:
    print("Good")
    print("*"*4)
elif attendance>=50 and attendance<70:
    print("Average")
    print("*"*3)
else:
    print("Poor")
    print("no rating")
# Out:
# Enter a Employee Attendance:  90
# Excellent
# *****

# %%
a=10
b=20 
c=30
if a>b and a>c:
    print(a)
elif b>c and b>a:
    print(b)
else:
    print(c)
# Out:
# 30

# %%
username=input("Enter a input:")

if username=="sumit":
   password=input("Enter a password: ")
   if password=="3452":
       print("Login Succesfully")
   else:
       print("You are password is wrong")
else:
     print("Your username is wrong..")
# Out:
# Enter a input: sumit
# Enter a password:  342
# You are password is wrong

# %%
# check the anual income match with civil score >75
income=int(input("Enter a income:"))
if income>100000:
    civil=int(input("Enter a civil score: "))
    if civil>=750:
        print("Loan approve.")
    else:
        print("You are civil is not good")
else:
    print("Your income is less..")
# Out:
# Enter a income: 453254
# Enter a civil score:  345
# You are civil is not good
